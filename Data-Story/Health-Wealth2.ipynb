# %% [markdown]
# # Data Story

# %% [markdown]
# ### Preliminaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Data Sets

# %%
tb1 = pd.read_csv('table_1.csv', index_col=None)

# %%
tb2 = pd.read_csv('table_2.csv', index_col=None)

# %% [markdown]
# ### Questions and answers

# %% [markdown]
# #### How many counts of male vs female are there in pooling 2001-2014 ?

# %%
# counts of male
count_m = tb1[tb1.gnd == 'M']['count'].sum()
print('Count of Male:', count_m)
# Out:
# Count of Male: 689956093

# %%
# counts of female
count_f = tb1[tb1.gnd == 'F']['count'].sum()
print('Count of Female:', count_f)
# Out:
# Count of Female: 718331125

# %%
tb1.groupby(by='gnd')['count'].sum().plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Counts of male & female in pooling 2001~2014')
plt.show()

# %%
# Count of Household Income Percentile
tb1.plot(kind='scatter', x='pctile', y='count')
plt.xlabel('Household Income Percentile')
plt.ylabel('Count')
plt.title('Count of Household Income Percentile')
plt.show()

# %% [markdown]
# In pooling 2001~2014, there are 689,956,093 male and 718,331,125 female whose data are collected. There are less people in the lowest 1% of household income.

# %% [markdown]
# #### What's the distrabution of mean household income

# %%
# distrabution of Mean Household Income
tb1.plot(kind='scatter', x='pctile', y='hh_inc', marker='.')
plt.xlabel('Household Income Percentile')
plt.ylabel('Mean Household Income')
plt.title('Distrabution of Household Income by Percentile')
plt.show()

# %%
# distrabution of Mean Household Income
tb1.plot(kind='scatter', x='pctile', y='hh_inc', marker='.')
plt.ylim(0, 550000)
plt.xlabel('Household Income Percentile')
plt.ylabel('Mean Household Income')
plt.title('Distrabution of Household Income by Percentile')
plt.show()

# %%
# distrabution of Mean Household Income, Age 40
tb1.plot(kind='scatter', x='pctile', y='hh_inc_age40', marker='.')
plt.xlabel('Household Income Percentile')
plt.ylabel('Mean Household Income')
plt.title('Distrabution of Household Income by Percentile')
plt.show()

# %%
# distrabution of Mean Household Income, Age 40
tb1.plot(kind='scatter', x='pctile', y='hh_inc_age40', marker='.')
plt.ylim(0, 550000)
plt.xlabel('Household Income Percentile')
plt.ylabel('Mean Household Income')
plt.title('Distrabution of Household Income by Percentile')
plt.show()

# %%
# distrabution of Mean Household Income in 2001~2014
tb2.plot(kind='scatter', x='pctile', y='hh_inc', marker='.')
plt.xlabel('Household Income Percentile')
plt.ylabel('Mean Household Income')
plt.title('Distrabution of Household Income by Percentile')
plt.show()

# %%
# distrabution of Mean Household Income in 2001~2014
tb2.plot(kind='scatter', x='pctile', y='hh_inc', marker='.')
plt.ylim(0, 550000)
plt.xlabel('Household Income Percentile')
plt.ylabel('Mean Household Income')
plt.title('Distrabution of Household Income by Percentile')
plt.show()

# %% [markdown]
# From above plots, we can see that people in highest 1 percentile has a lot more household income than that of the other 99 percentiles.

# %% [markdown]
# #### What's the distrabutions of life expectancy

# %%
# distrabution of life expectancy of male
tb1_m = tb1[tb1.gnd == 'M']
plt.hist(tb1_m.le_raceadj, bins=25, color=sns.color_palette("Set2", 1))
plt.title('Life Expectancy of Male')
plt.show()

# %%
# distrabution of life expectancy of female
tb1_f = tb1[tb1.gnd == 'F']
plt.hist(tb1_f.le_raceadj, bins=25, color=sns.color_palette("Set1", 1))
plt.title('Life Expectancy of Female')
plt.show()

# %%
# distrabution of life expectancy of male
sns.kdeplot(tb1_m.le_raceadj, shade=True)
plt.show()
# Out:
# /home/toniachu/ProgramFiles/Anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# distrabution of life expectancy of male
sns.kdeplot(tb1_f.le_raceadj, shade=True)
plt.show()
# Out:
# /home/toniachu/ProgramFiles/Anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
# Boxplot of life expectancy, male and female
sns.boxplot(tb1.le_raceadj, tb1.gnd, order=["M", "F"], palette="Set2", saturation=1)
plt.ylabel('Gender')
plt.xlabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy by Gender')
plt.show()

# %%
sns.boxplot(x="gnd", y="le_raceadj", data=tb2, order=["M", "F"], palette="Set2", saturation=1)
plt.xlabel('Gender')
plt.ylabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy by Gender')
plt.show()

# %%
# distrabution of life expectancy
tb1.plot(kind='scatter', x='pctile', y='le_raceadj')
plt.xlabel('Household Income Percentile')
plt.ylabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy by Household Income Percentile')
plt.show()

# %%
# distrabution of life expectancy in 2001~2014
tb2.plot(kind='scatter', x='pctile', y='le_raceadj', marker='.')
plt.xlabel('Household Income Percentile')
plt.ylabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy by Household Income Percentile')
plt.show()

# %%
# Scatter plot of life expectancy by mean household income
tb1.plot(kind='scatter', x='hh_inc', y='le_raceadj')
plt.xlim(0, 550000)
plt.xlabel('Mean Household Income ')
plt.ylabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy by Mean Household Income')
plt.show()

# %%
# Scatter plot of life expectancy by mean household income in 2001~2014
tb2.plot(kind='scatter', x='hh_inc', y='le_raceadj', marker='.')
plt.xlim(0, 550000)
plt.xlabel('Mean Household Income ')
plt.ylabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy by Mean Household Income')
plt.show()

# %% [markdown]
# From above plots, we can see that females' life expectancy are higher than males' life expectancy. The bigger the household income is, the highter the life expectancy is. For the people whose household income are in the lowest 5 percentile, their life expectancies are much lower than other people. The life ecpectancy difference of male and female are smaller than others for the people whose household income are in the highest 10 percentile. For people whose mean household income are below 100,100USD, their life expectancy difference are bigger by different income. But for people whose mean household income are over 200,000USD, their life expectancy difference are not distinct  by different income.

# %% [markdown]
# ### What's the trend of life expectancy from 2001 to 2014

# %%
# Boxplot of life expectancy, in 2001~2014
sns.boxplot(x="year", y="le_raceadj", data=tb2, palette="Set3", saturation=1, fliersize=3)
plt.xlabel('Year')
plt.ylabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy From 2001 to 2014')
plt.show()

# %%
# Boxplot of life expectancy, male and female, in 2001~2014
sns.boxplot(x="year", y="le_raceadj", hue="gnd", data=tb2, hue_order=["M", "F"], palette="Set3")
plt.xlabel('Year')
plt.ylabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy From 2001 to 2014')
plt.show()

# %%
# Boxplot of life expectancy, male and female, in 2001~2014
sns.boxplot(x="gnd", y="le_raceadj", hue="year", data=tb2, order=["M", "F"], palette="Set2", saturation=1, fliersize=3)
plt.xlabel('Year')
plt.ylabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy From 2001 to 2014')
plt.show()

# %%
# trend of life expectancy from 2001 to 2014 for Household Income Percentile 5
tb2[tb2.pctile == 5].plot(kind='scatter', x='year', y='le_raceadj', marker='o')
plt.xlabel('Year')
plt.ylabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy From 2001 to 2014')
plt.text(2001, 79, 'Percentile 5')
plt.show()

# %%
# trend of life expectancy from 2001 to 2014 for Household Income Percentile 50
tb2[tb2.pctile == 50].plot(kind='scatter', x='year', y='le_raceadj', marker='o')
plt.xlabel('Year')
plt.ylabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy From 2001 to 2014')
plt.text(2001, 87, 'Percentile 50')
plt.show()

# %%
# trend of life expectancy from 2001 to 2014 for Household Income Percentile 95
tb2[tb2.pctile == 95].plot(kind='scatter', x='year', y='le_raceadj', marker='o')
plt.xlabel('Year')
plt.ylabel('Race-Adjusted Life Expectancy')
plt.title('Life Expectancy From 2001 to 2014')
plt.text(2001, 90, 'Percentile 95')
plt.show()

# %% [markdown]
# From above plots, we can see that averge life expectancy increased from 2001 to 2014, especialy before 2007. After 2007, the life expectancy increased steadly. For people whose life expectancy are in the lowest 5 percentile, there's nearly no increase. For people in the highest 5 percentile, there are big increase.

# %% [markdown]
# ### What's the trend of household income from 2001 to 2014

# %%
# Boxplot of Mean Household Income, in 2001~2014
sns.boxplot(x="year", y="hh_inc", data=tb2, palette="Set3", saturation=1, fliersize=3)
plt.ylim(0, 300000)
plt.xlabel('Year')
plt.ylabel('Mean Household Income')
plt.title('Mean Household Income from 2001 to 2014')
plt.show()

# %%
# Boxplot of Mean Household Income, male and female, in 2001~2014
sns.boxplot(x="year", y="hh_inc", hue="gnd", data=tb2, hue_order=["M", "F"], palette="Set3")
plt.ylim(0, 300000)
plt.xlabel('Year')
plt.ylabel('Mean Household Income')
plt.title('Mean Household Income from 2001 to 2014')
plt.show()

# %%
# Bar chart of mean household income in 2001~2014
tb2.groupby(['year'])[['hh_inc']].mean().plot(kind='bar')
plt.xlabel('Year')
plt.title('Mean Household Income from 2001 to 2014')
plt.show()

# %%
# Bar chart of mean household income in 2001~2014 for male and female
tb2.groupby(['year', 'gnd'])[['hh_inc']].mean().plot(kind='bar')
plt.xlabel('Year')
plt.title('Mean Household Income from 2001 to 2014')
plt.show()

# %% [markdown]
# From above plots, we can see that mean household income slighly decreased from 2001 to 2014. 2004, 2011 and 2014 are the years of lowest income. Males' incomes are higher than that of females in each year.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# In this research, we worked on the distrabusion and relationship of mean household income and life expectancy of males vs females in year 2001 to 2014. We can draw following conclusions from our research:
#
# 1. Mean household income of Americans are not equal. 1% people have 20 times more income than that of other 99% people. Nearly 1% people are very poor. They have 100 times less income than people in the average level.
#
# 2. Males have higher income than females, but their life expectancies are lower than females. Life expectancy difference of males and females in the lowest 5 percentiles are higher than people in the highest 20 percentiles.
#
# 3. People with higher household income have higher life expectancy. From 2001 to 2014, though the mean household income of people are slighly decreased, life expectancy increased, especially for the rich people.
#
# 4. For the people whose household income are in the lowest 5 percentile, their life expectancies are much lower than other people. For people whose mean household income are below 100,100USD, their life expectancy difference are bigger by different income. But for people whose mean household income are over 200,000USD, their life expectancy difference are not distinct by different income.
